# %%
print("This is my print")
# Out:
# This is my print

# %%
l=[345,45,45,45]

# %%
len(l)
# Out:
# 4

# %%
type(l)
# Out:
# list

# %%
def test():
    pass    #if no denifinition of function then use pass it will not give error

# %%
def test1():
    print("this is my very very first function") 
#On executing this it will not run we have to call this function to make it run

# %%
test1() #calling the function
# Out:
# this is my very very first function

# %%
test1()+"sudh" #print returns "NoneType" so on concatenating "NoneType" with string "sudh" it will give error
# Out:
# this is my very very first function
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 test1()+"sudh"
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'str'

# %%
def test2():
    return "this is my very first return"  #Now i can concatenate string "sudh"

# %%
test2()+ "sudh"  #Now it will not give error so we have to use return keyword to return any type
# Out:
# 'this is my very first returnsudh'

# %%
def test3():
    return "sudh", 23,345.56,[1,2,3,3] #we can return multiple datatype at once

# %%
test3() #on caalling datatype it returns every datatype inside a tuple
# Out:
# ('sudh', 23, 345.56, [1, 2, 3, 3])

# %%
a,b,c,d=test3() #a will be assined "sudh" , b will be assigned 23 ,c will ve assined 345.56 and d will be assigned [1,2,3,3]

# %%
a
# Out:
# 'sudh'

# %%
b
# Out:
# 23

# %%
c
# Out:
# 345.56

# %%
d
# Out:
# [1, 2, 3, 3]

# %%
def test4():
    a=5+6/7
    return a

# %%
test4()
# Out:
# 5.857142857142857

# %%
def test5(a,b,c):
    d=a+b/c
    return d

# %%
test5() #it will give error because we have not specified the values of a,b,c
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 test5() #it will give error because we have not specified the values of a,b,c
#
# TypeError: test5() missing 3 required positional arguments: 'a', 'b', and 'c'

# %%
test5(2,5,8)
# Out:
# 2.625

# %%
def test6(a,b):
    return a+b

# %%
test6(3,4) #function test6(a,b) will add the value and returns it
# Out:
# 7

# %%
test6("sudh","kumar") #function test6(a,b) will concatenate both strings and returns the output
# Out:
# 'sudhkumar'

# %%
test6([1,2,3,4,5],[4,5,6]) #function test6(a,b) will merge both list
# Out:
# [1, 2, 3, 4, 5, 4, 5, 6]

# %%
l=[1,2,3,4,"sudh","kumar",[1,2,3,4,5,6]]

# %%
def test8(l):
    l1=[]
    for i in l:
        if type(i)==int:
            l1.append(i)
        else:
            type(i)==list
            for k in i:
                if type(k)==int:
                    l1.append(k)
    return l1

# %%
test8(l)
# Out:
# [1, 2, 3, 4, 1, 2, 3, 4, 5, 6]

# %%
test8() #if we press shift+tab while curser is inside paranthisis of test8() here it says no docstring

# %%
len() #but if we press shift+tab while curser is inside paranthisis of test8() it will give Docstring: Return the number of items in a container.

# %%
#To add doctstring 

def test9(l):
    """This is my function to extract numreic data from list""" #This is called Docstring
    l1=[]
    for i in l:
        if type(i)==int:
            l1.append(i)
        else:
            type(i)==list
            for k in i:
                if type(k)==int:
                    l1.append(k)
    return l1

# %%
test9() #if we press shift+tab while curser is inside paranthisis of test9() it will give Docstring: This is my function to extract numreic data from list

# %%
def test10(a,b): #i want to make the paramter inside paranthisis dynamic means what ever input or any number of input user gave it takes accordingly
    return a+b

# %%
def test11(*args): # * means n number of arguments you can pass inside function 
    return args

# %%
type(test11())
# Out:
# tuple

# %%
test11(1,2,3)
# Out:
# (1, 2, 3)

# %%
test11(1,2,3,"sudh","kumar",[1,2,3,4,4]) #i can pass anything and any number of arguments to function test11() and returns the arguments as tuple
# Out:
# (1, 2, 3, 'sudh', 'kumar', [1, 2, 3, 4, 4])

# %%
def test12(*sudh): # *args is jus a convention we can use any name with * to pass any number of arguments
    return sudh

# %%
test12(1,2,34,4)
# Out:
# (1, 2, 34, 4)

# %%
def test13(*args, a):
    return args, a

# %%
test13(1,2,3,4) #it is confused to which parameter args or a we have supplied the input
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 test13(1,2,3,4) #it is confused to which parameter args or a we have supplied the input
#
# TypeError: test13() missing 1 required keyword-only argument: 'a'

# %%
test13(1,2,3,4,a=23) #now it will not give error
# Out:
# ((1, 2, 3, 4), 23)

# %%
def test14(c,d,a=23,b=1):
    return a,b,c,d

# %%
test14()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 test14()
#
# TypeError: test14() missing 2 required positional arguments: 'c' and 'd'

# %%
test14(3,4)
# Out:
# (23, 1, 3, 4)

# %%
test14(2,5,a=2342) #if we dont supply the value of a and b default value that is a=23 and b=1 will be used
# Out:
# (2342, 1, 2, 5)

# %%
def test15(**kwargs): #for linear value we use * and if want to reurn key:value pair that is dictionary we use **
    return kwargs

# %%
test15() #it is returning dictionary
# Out:
# {}

# %%
type(test15())
# Out:
# dict

# %%
test15(a=[1,2,3,4], b="sudh",c=23.45) #it returns a as key and [1,2,3,4] as value of a, b as key and "sudh" as value of b,c=23.45
# Out:
# {'a': [1, 2, 3, 4], 'b': 'sudh', 'c': 23.45}
