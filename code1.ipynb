# %%
True/False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 True/False
#
# ZeroDivisionError: division by zero

# %%
v= 5+ 8j
type(v)
# Out:
# complex

# %%
v.real
# Out:
# 5.0

# %%
v.imag
# Out:
# 8.0

# %%
print("My name is Amitesh")
# Out:
# My name is Amitesh

# %%
print(v)
# Out:
# (5+8j)

# %%
s="pwskills"
type(s)
# Out:
# str

# %%
s[0]
# Out:
# 'p'

# %%
s[1]
# Out:
# 'w'

# %%
s[3]
# Out:
# 'k'

# %%
s[-1]
# Out:
# 's'

# %%
s[-2]
# Out:
# 'l'

# %%
s[-3]
# Out:
# 'l'

# %%
s[-8]
# Out:
# 'p'

# %%
s[0:3] #start from 0 index and end at third index
# Out:
# 'pws'

# %%
s[0]

# %%
s[0:4]
# Out:
# 'pwsk'

# %%
s[0:8:2]
# Out:
# 'psil'

# %%
s[::2]
# Out:
# 'psil'

# %%
s[2::2]
# Out:
# 'sil'

# %%
s[::-1] #reverse direction
# Out:
# 'sllikswp'

# %%
s[2:7:-1] #start from 2 and ends at 7 but jumping backwards so direction mismatch
# Out:
# ''

# %%
s[8:0] #starting from 8 ending at 0 so backward direction and step is bydefault 1 so positive direction both mismatch
# Out:
# ''

# %%
s[8:0:-1] #starting from 8 and end at 0 backward direction and step -1 backward direction so direction smatch but 0 upperbound so no p in output
# Out:
# 'slliksw'

# %%
s[-2:-8:1]
# Out:
# ''

# %%
s[-2::-1]
# Out:
# 'llikswp'

# %%
s[::-1]
# Out:
# 'sllikswp'

# %%
s[:-90000:-1]
# Out:
# 'sllikswp'

# %%
s1="this is my string class"
len(s1)
# Out:
# 23

# %%
s1.find("s")
# Out:
# 3

# %%
s1.find("i")
# Out:
# 2

# %%
s1.find("is")
# Out:
# 2

# %%
s1.count("s")
# Out:
# 5

# %%
s1.count("z")
# Out:
# 0

# %%
s1
# Out:
# 'this is my string class'

# %%
s1.upper()
# Out:
# 'THIS IS MY STRING CLASS'

# %%
s2="THIS IS MY STRING CLASS"

# %%
s2.lower()
# Out:
# 'this is my string class'

# %%
s1
# Out:
# 'this is my string class'

# %%
s1.title()
# Out:
# 'This Is My String Class'

# %%
s1.capitalize()
# Out:
# 'This is my string class'

# %%
s+1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 s+1
#
# TypeError: can only concatenate str (not "int") to str

# %%
s+" sudh"
# Out:
# 'pwskills sudh'

# %%
s+"1" #or s + str(1)
# Out:
# 'pwskills1'

# %%
s*3
# Out:
# 'pwskillspwskillspwskills'

# %%
"sudh"*3
# Out:
# 'sudhsudhsudh'

# %%
"sudh"/4 #not a valid operation
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 "sudh"/4
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
"don't do copy and paste in my class" #no error
# Out:
# "don't do copy and paste in my class"

# %%
"Don"t do copy and paste in my class"       #but here error
# Out:
#   Cell In[31], line 1
#     "Don"t do copy and paste in my class"       #but here error
#                                         ^
# SyntaxError: unterminated string literal (detected at line 1)
