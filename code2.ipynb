# %%
l=[1,345,45,"sudh",True,5+7j,345.456]

# %%
type(l)
# Out:
# list

# %%
l[0]
# Out:
# 1

# %%
l[6]
# Out:
# 345.456

# %%
l[90]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 l[90]
#
# IndexError: list index out of range

# %%
l[0:3]
# Out:
# [1, 345, 45]

# %%
l[-1]
# Out:
# 345.456

# %%
l[-1::]
# Out:
# [345.456]

# %%
l[::-1]
# Out:
# [345.456, (5+7j), True, 'sudh', 45, 345, 1]

# %%
l[::2]
# Out:
# [1, 45, True, 345.456]

# %%
s="pwskills"

# %%
l+s
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 l+s
#
# TypeError: can only concatenate list (not "str") to list

# %%
list(s)+l
# Out:
# ['p',
#  'w',
#  's',
#  'k',
#  'i',
#  'l',
#  'l',
#  's',
#  1,
#  345,
#  45,
#  'sudh',
#  True,
#  (5+7j),
#  345.456]

# %%
l

# %%
type(l[3])
# Out:
# str

# %%
l[3][0:2]
# Out:
# 'su'

# %%
str(l[4])[0:2]
# Out:
# 'Tr'

# %%
l1=[3,4,5]

# %%
l+l1
# Out:
# [1, 345, 45, 'sudh', True, (5+7j), 345.456, 3, 4, 5]

# %%
l1*3
# Out:
# [3, 4, 5, 3, 4, 5, 3, 4, 5]

# %%
l
# Out:
# [1, 345, 45, 'sudh', True, (5+7j), 345.456]

# %%
l.append(5) #append functions appends the data at the last index as it is

# %%
l
# Out:
# [1, 345, 45, 'sudh', True, (5+7j), 345.456, 5]

# %%
l.append(s)

# %%
l
# Out:
# [1, 345, 45, 'sudh', True, (5+7j), 345.456, 5, 'pwskills', 'pwskills']

# %%
l.append(l1)

# %%
l
# Out:
# [1,
#  345,
#  45,
#  'sudh',
#  True,
#  (5+7j),
#  345.456,
#  5,
#  'pwskills',
#  'pwskills',
#  [3, 4, 5]]

# %%
l[-1][1]
# Out:
# 4

# %%
l.extend(4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 l.extend(4)
#
# TypeError: 'int' object is not iterable

# %%
l.extend("sudh") #extend function first breaks the data and then adds it

# %%
l
# Out:
# [1,
#  345,
#  45,
#  'sudh',
#  True,
#  (5+7j),
#  345.456,
#  5,
#  'pwskills',
#  'pwskills',
#  [3, 4, 5],
#  's',
#  'u',
#  'd',
#  'h']

# %%
l.extend([3,4,5]) #extend breaks the list [3,4,5] and adds 3,4,5 into the list

# %%
l
# Out:
# [1,
#  345,
#  45,
#  'sudh',
#  True,
#  (5+7j),
#  345.456,
#  5,
#  'pwskills',
#  'pwskills',
#  [3, 4, 5],
#  's',
#  'u',
#  'd',
#  'h',
#  3,
#  4,
#  5]

# %%
l1
# Out:
# [3, 4, 5]

# %%
l1.insert(2,[2,3,4]) #insert the list at index 2

# %%
l1
# Out:
# [3, 4, [2, 3, 4], 5]

# %%
l1.insert(2,[2,3,4])

# %%
l1
# Out:
# [3, 4, [2, 3, 4], [2, 3, 4], 5]

# %%
l1.insert(-1,45) #insert the element 45 at index -1 and shift the position of element at index -1 to right

# %%
l1
# Out:
# [3, 4, [2, 3, 4], [2, 3, 4], 45, 5]

# %%
l1.insert(0,45)

# %%
l1
# Out:
# [45, 3, 4, [2, 3, 4], [2, 3, 4], 45, 5]

# %%
l1.pop() #pops the element at specified index.by default pops at -1 index if not specified
# Out:
# 5

# %%
l1.pop()
# Out:
# 45

# %%
l1
# Out:
# [45, 3, 4, [2, 3, 4], [2, 3, 4]]

# %%
l1.remove(3) #will remove the specified element
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 l1.remove(3) #will remove the specified element
#
# ValueError: list.remove(x): x not in list

# %%
l1
# Out:
# [45, 4, [2, 3, 4], [2, 3, 4]]

# %%
l1[3].pop(1) #removes elemnt 3 of list [2,3,4] at index 3
# Out:
# 3

# %%
l1
# Out:
# [45, 4, [2, 3, 4], [2, 4]]

# %%
#if i want to remove dh from "sudh" it cant be possible becoz string is immuatble but list mutable

# %%
l1.append(4)
l1
# Out:
# [45, 4, [2, 3, 4], [2, 4], 4]

# %%
l1.remove(4) #will remove the first occurence of 4

# %%
l1
# Out:
# [45, [2, 3, 4], [2, 4], 4]

# %%
l1[::-1] #temporary reverse but orignal list will not reverse
# Out:
# [4, [2, 4], [2, 3, 4], 45]

# %%
l1.reverse() #will reverse the orignal list

# %%
l1
# Out:
# [4, [2, 4], [2, 3, 4], 45]

# %%
l2=[45,23,90,0,3,4,5,6,7,8,9]

# %%
l2.sort() #will sort the elements in ascending order

# %%
l2
# Out:
# [0, 3, 4, 5, 6, 7, 8, 9, 23, 45, 90]

# %%
l3=[34,"sudh",45,12,"kumar"]

# %%
l3.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 l3.sort()
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
l4=["sudh","kumar","pwskills","data science"]

# %%
l4.sort() #sorts in ascending order of alphabet by default (reverse=false)

# %%
l4
# Out:
# ['data science', 'kumar', 'pwskills', 'sudh']

# %%
l4.sort(reverse=True) #now it sorts in descending order

# %%
l4
# Out:
# ['sudh', 'pwskills', 'kumar', 'data science']

# %%
l4.index("sudh") #return the index of the element
# Out:
# 0

# %%
l4.count("count") #total number of occurence of that element
# Out:
# 0

# %%
s="sudh"

# %%
l5=[3,4,5,6]

# %%
s[0]="a" #strings are immutable so error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 s[0]="a"
#
# TypeError: 'str' object does not support item assignment

# %%
l5[0]=30 #list are mutable so no error

# %%
l5
# Out:
# [30, 4, 5, 6]

# %%
s.replace("s","a") #This will give the result by replcing s with a but will not change orignal list
# Out:
# 'audh'

# %%
s #The orignal list is still same
# Out:
# 'sudh'

# %%
t=(2,3,4,5,"sudh",45.56,False,45+457j,[3,4,5])

# %%
t
# Out:
# (2, 3, 4, 5, 'sudh', 45.56, False, (45+457j), [3, 4, 5])

# %%
type(t)
# Out:
# tuple

# %%
len(t)
# Out:
# 9

# %%
t[0]
# Out:
# 2

# %%
t[-1]
# Out:
# [3, 4, 5]

# %%
t[::-1]
# Out:
# ([3, 4, 5], (45+457j), False, 45.56, 'sudh', 5, 4, 3, 2)

# %%
l4
# Out:
# ['sudh', 'pwskills', 'kumar', 'data science']

# %%
l4[0]=23424

# %%
l4
# Out:
# [23424, 'pwskills', 'kumar', 'data science']

# %%
t
# Out:
# (2, 3, 4, 5, 'sudh', 45.56, False, (45+457j), [3, 4, 5])

# %%
t[0]="sudh" #tuples are immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 t[0]="sudh" #tuples are immutable
#
# TypeError: 'tuple' object does not support item assignment

# %%
t[::-1]
# Out:
# ([3, 4, 5], (45+457j), False, 45.56, 'sudh', 5, 4, 3, 2)

# %%
t.count(5)
# Out:
# 1

# %%
t.index(False)
# Out:
# 6

# %%
t
# Out:
# (2, 3, 4, 5, 'sudh', 45.56, False, (45+457j), [3, 4, 5])

# %%
s1={}

# %%
type(s1)
# Out:
# dict

# %%
s2={2,3,4,55,6}

# %%
type(s2)
# Out:
# set

# %%
s3={324,456,456,"sudh",45+45j,34.465,(3,4,5)}

# %%
s3
# Out:
# {(3, 4, 5), (45+45j), 324, 34.465, 456, 'sudh'}

# %%
type(s3)
# Out:
# set

# %%
s4={2,3,4,5,6,2,2,3,4,5,2,3,1,2,3,4,5,6,1,2,2,3,"Sudh","sudh"}

# %%
s4    #python is case sensitive so will not remove both sudh as one is capital S and other is small s
# Out:
# {1, 2, 3, 4, 5, 6, 'Sudh', 'sudh'}

# %%
s4={2,3,4,5,6,2,2,3,4,5,2,3,1,2,3,4,5,6,1,2,2,3,"Sudh","sudh"}

# %%
s4
# Out:
# {1, 2, 3, 4, 5, 6, 'Sudh', 'sudh'}

# %%
l6={2,3,4,5,6,2,2,3,4,5,2,3,1,2,3,4,5,6,1,2,2,3,"Sudh","sudh"}

# %%
l6=list(set(l6)) #A function set() is also there to eliminate duplicate values

# %%
l6
# Out:
# [1, 2, 3, 4, 5, 6, 'Sudh', 'sudh']

# %%
s5={234,45,23,12,567,45,2,789,234,"abc",456,342,23}

# %%
s5
# Out:
# {12, 2, 23, 234, 342, 45, 456, 567, 789, 'abc'}

# %%
s5[0]   #we can't access the object inside set like we used to do in list , tuple and string
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 s5[0]
#
# TypeError: 'set' object is not subscriptable

# %%
s5[::-1] #slicing also not applicable in case of set

# %%
s5.add(4)

# %%
s5
# Out:
# {12, 2, 23, 234, 342, 4, 45, 456, 567, 789, 'abc'}

# %%
s5.remove(2)

# %%
s5
# Out:
# {12, 23, 234, 342, 4, 45, 456, 567, 789, 'abc'}
